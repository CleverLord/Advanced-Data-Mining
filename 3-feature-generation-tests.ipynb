# %% [markdown]
# # Feature generation

# %%
import pandas as pd
import spacy
import os

from feature_generation_functions import *

# %% [markdown]
# ## load spacy

# %%
nlp = spacy.load("pl_core_news_sm")

# %% [markdown]
# ## Path

# %%
root_dir = os.path.abspath(os.path.join(os.getcwd()))
print(root_dir)
# Out:
# /home/lizardman/Uczelnia/DataMining/Advanced-Data-Mining

# %% [markdown]
# ## Read cleaned data from pickle

# %%
path_to_pickle = os.path.join(root_dir, 'data_cleaning-data', 'tematy_i_opisy_df_cleaned.pickle')
df_main: pd.DataFrame = pd.read_pickle(path_to_pickle)

# %% [markdown]
# ## columns selection

# %%
columns = df_main.columns
cols_names = columns.tolist()
cols_names = [cols_names[0], cols_names[1], cols_names[5]]
print(cols_names)
# Out:
# ['Tytuł pracy w języku oryginału', 'Temat Pracy', 'Typ pracy']

# %% [markdown]
# ## df with interesting columns

# %%
df = get_df_with_columns(df_main, cols_names)
df
# Out:
#                          Tytuł pracy w języku oryginału  \
# 0     Rozwój funkcjonalności oraz modernizacja konst...
# 1     Opracowanie rusztowania na bazie wełny owczej ...
# 2     Papierowe systemy analityczne z mikroprzepływe...
# 3     System wizyzjny odczytujący osobom niewidomym ...
# 4     System wizyzjny nakierowujący osoby niewidome ...
# ...                                                 ...
# 5306                Biznesplan sklepu z odzieżą używaną
# 5307  Ewolucja bankowości elektronicznej w Polsce na...
# 5308  Ocena wykonania budżetu jednostki samorządu te...
# 5309  Rozwiązania smart-city stosowane dla krakowski...
# 5310  Analiza pierwotnego rynku nieruchomości lokalo...
#
#                                             Temat Pracy    Typ pracy
# 0     Tematem niniejszej pracy jest rozwój funkcjona...  magisterska
# 1     Niniejsza praca dyplomowa skupia się na opraco...  inżynierska
# 2     Praca dotyczy prostych systemów diagnostycznyc...  inżynierska
# 3     Celem pracy jest stworzenie systemu wizyjnego,...  inżynierska
# 4     Celem pracy jest stworzenie systemu wizyjnego,...  inżynierska
# ...                                                 ...          ...
# 5306  W pracy zostaną przedstawione kolejne etapy po...  licencjacka
# 5307  W pracy dokonano opisu rozwoju bankowości elek...  licencjacka
# 5308  W pracy zostanie przedstawiony planowany budże...  licencjacka
# 5309  W pracy przedstawione zostanie zainteresowanie...  inżynierska
# 5310  Praca wymaga przeprowadzenia analizy statystyc...  inżynierska
#
# [5311 rows x 3 columns]

# %% [markdown]
# ## rename columns

# %%
new_names = ['title', 'description', 'category']
for i in range(len(cols_names)):
    df = rename_columns(df, cols_names[i], new_names[i])
df
# Out:
#                                                   title  \
# 0     Rozwój funkcjonalności oraz modernizacja konst...
# 1     Opracowanie rusztowania na bazie wełny owczej ...
# 2     Papierowe systemy analityczne z mikroprzepływe...
# 3     System wizyzjny odczytujący osobom niewidomym ...
# 4     System wizyzjny nakierowujący osoby niewidome ...
# ...                                                 ...
# 5306                Biznesplan sklepu z odzieżą używaną
# 5307  Ewolucja bankowości elektronicznej w Polsce na...
# 5308  Ocena wykonania budżetu jednostki samorządu te...
# 5309  Rozwiązania smart-city stosowane dla krakowski...
# 5310  Analiza pierwotnego rynku nieruchomości lokalo...
#
#                                             description     category
# 0     Tematem niniejszej pracy jest rozwój funkcjona...  magisterska
# 1     Niniejsza praca dyplomowa skupia się na opraco...  inżynierska
# 2     Praca dotyczy prostych systemów diagnostycznyc...  inżynierska
# 3     Celem pracy jest stworzenie systemu wizyjnego,...  inżynierska
# 4     Celem pracy jest stworzenie systemu wizyjnego,...  inżynierska
# ...                                                 ...          ...
# 5306  W pracy zostaną przedstawione kolejne etapy po...  licencjacka
# 5307  W pracy dokonano opisu rozwoju bankowości elek...  licencjacka
# 5308  W pracy zostanie przedstawiony planowany budże...  licencjacka
# 5309  W pracy przedstawione zostanie zainteresowanie...  inżynierska
# 5310  Praca wymaga przeprowadzenia analizy statystyc...  inżynierska
#
# [5311 rows x 3 columns]

# %% [markdown]
# ## eliminate empty descriptions

# %%
# df = change_polish_letters(df, 'description')
df = remove_empty_description(df, 'description')
df
# Out:
#                                                   title  \
# 0     Rozwój funkcjonalności oraz modernizacja konst...
# 1     Opracowanie rusztowania na bazie wełny owczej ...
# 2     Papierowe systemy analityczne z mikroprzepływe...
# 3     System wizyzjny odczytujący osobom niewidomym ...
# 4     System wizyzjny nakierowujący osoby niewidome ...
# ...                                                 ...
# 5306                Biznesplan sklepu z odzieżą używaną
# 5307  Ewolucja bankowości elektronicznej w Polsce na...
# 5308  Ocena wykonania budżetu jednostki samorządu te...
# 5309  Rozwiązania smart-city stosowane dla krakowski...
# 5310  Analiza pierwotnego rynku nieruchomości lokalo...
#
#                                             description     category
# 0     Tematem niniejszej pracy jest rozwój funkcjona...  magisterska
# 1     Niniejsza praca dyplomowa skupia się na opraco...  inżynierska
# 2     Praca dotyczy prostych systemów diagnostycznyc...  inżynierska
# 3     Celem pracy jest stworzenie systemu wizyjnego,...  inżynierska
# 4     Celem pracy jest stworzenie systemu wizyjnego,...  inżynierska
# ...                                                 ...          ...
# 5306  W pracy zostaną przedstawione kolejne etapy po...  licencjacka
# 5307  W pracy dokonano opisu rozwoju bankowości elek...  licencjacka
# 5308  W pracy zostanie przedstawiony planowany budże...  licencjacka
# 5309  W pracy przedstawione zostanie zainteresowanie...  inżynierska
# 5310  Praca wymaga przeprowadzenia analizy statystyc...  inżynierska
#
# [5132 rows x 3 columns]

# %% [markdown]
# ## Tokenizing column

# %%
df = tokenize_column(df, nlp, 'description', 'description_tokens')

# %%
df['description_tokens'][0]
# Out:
# ['Tematem',
#  'niniejszej',
#  'pracy',
#  'jest',
#  'rozwój',
#  'funkcjonalności',
#  'oraz',
#  'konstrukcji',
#  'maszyny',
#  'realizującej',
#  'proces',
#  'beznarzędziowego',
#  'ciągnienia',
#  '.',
#  '\n',
#  'Przebudowanie',
#  'systemu',
#  'transportu',
#  'układu',
#  'grzewczego',
#  'umożliwi',
#  'zminimalizowanie',
#  'zakłóceń',
#  'procesu',
#  'beznarzędziowego',
#  'ciągnienia',
#  'takich',
#  'jak',
#  'drgania',
#  'systemu',
#  ',',
#  'które',
#  'wynikają',
#  'z',
#  'zastosowania',
#  'niskobudżetowego',
#  'napędu',
#  'liniowego',
#  '.',
#  'Efektem',
#  'tych',
#  'działań',
#  'będzie',
#  'otrzymanie',
#  'próbek',
#  'oraz',
#  'danych',
#  'z',
#  'procesu',
#  'beznarzędziowego',
#  'ciągnienia',
#  'o',
#  'wyższej',
#  'jakości',
#  '.',
#  '\n',
#  'Adaptacja',
#  'kodu',
#  'aplikacji',
#  'do',
#  'pracy',
#  'na',
#  'komputerze',
#  'stacjonarnym',
#  'zwiększy',
#  'częstotliwości',
#  'odczytu',
#  'wartości',
#  'z',
#  'czujnika',
#  'siły',
#  ',',
#  'wykonywania',
#  'zdjęć',
#  'próbki',
#  'oraz',
#  'podniesie',
#  'wydajność',
#  'algorytmu',
#  'analizującego',
#  'obraz',
#  'i',
#  'wyliczającego',
#  'wartość',
#  'odkształcenia',
#  'próbki',
#  '.',
#  'Wynikiem',
#  'zwiększenia',
#  'wydajności',
#  'tych',
#  'operacji',
#  'jest',
#  'uzyskanie',
#  'dokładniejszych',
#  'wykresów',
#  'naprężenia',
#  'od',
#  'odkształcenia',
#  'oraz',
#  'siły',
#  'od',
#  'wydłużenia',
#  'próbki',
#  '.',
#  'Ponadto',
#  'umożliwi',
#  'to',
#  'wykonywanie',
#  'statycznych',
#  'prób',
#  'rozciągania',
#  'przy',
#  'większych',
#  'prędkościach',
#  'odkształcenia',
#  'próbki',
#  '.',
#  '\n',
#  'Zamontowanie',
#  'enkodera',
#  'absolutnego',
#  'na',
#  'wale',
#  'silnika',
#  'odpowiedzialnego',
#  'za',
#  'rozciąganie',
#  'próbki',
#  'pozwoli',
#  'na',
#  'odczytywanie',
#  'jego',
#  'dokładnej',
#  'pozycji',
#  'w',
#  'dowolnym',
#  'momencie',
#  'trwania',
#  'procesu',
#  ',',
#  'a',
#  'także',
#  'umożliwi',
#  'pomiar',
#  'ilości',
#  'wykonanych',
#  'przez',
#  'silnik',
#  'kroków',
#  '.',
#  'Zaimplementowanie',
#  'algorytmu',
#  'wykorzystującego',
#  'te',
#  'dane',
#  'umożliwi',
#  'odczytywanie',
#  'zmiany',
#  'odkształcenia',
#  'oraz',
#  'średnicy',
#  'próbki',
#  'w',
#  'czasie',
#  'rzeczywisty',
#  ',',
#  'a',
#  'także',
#  'pozwoli',
#  'na',
#  'kontrolowanie',
#  'prędkości',
#  'odkształcenia',
#  'materiału',
#  '.']

# %%
df1 = tokenize_column(df, nlp, 'title', 'title_tokens')
df1['title_tokens'][0]
# Out:
# ['Rozwój',
#  'funkcjonalności',
#  'oraz',
#  'modernizacja',
#  'konstrukcji',
#  'maszyny',
#  'realizującej',
#  'proces',
#  'beznarzędziowego',
#  'ciągnienia']

# %%
path_to_feature_data = os.path.join(root_dir, 'feature_generation-data')
path_to_basic_feture_pickle = os.path.join(path_to_feature_data, 'basic_features_df.pickle')

# with open(path_to_basic_feture_pickle, 'wb') as f:
#     df1.to_pickle(f)
    
df: pd.DataFrame = pd.read_pickle(path_to_basic_feture_pickle)

# %% [markdown]
# ## till here tokenized description and title and everythink works

# %%
df['description_tokens'][0]
# Out:
# ['Tematem',
#  'niniejszej',
#  'pracy',
#  'jest',
#  'rozwój',
#  'funkcjonalności',
#  'oraz',
#  'konstrukcji',
#  'maszyny',
#  'realizującej',
#  'proces',
#  'beznarzędziowego',
#  'ciągnienia',
#  '.',
#  '\n',
#  'Przebudowanie',
#  'systemu',
#  'transportu',
#  'układu',
#  'grzewczego',
#  'umożliwi',
#  'zminimalizowanie',
#  'zakłóceń',
#  'procesu',
#  'beznarzędziowego',
#  'ciągnienia',
#  'takich',
#  'jak',
#  'drgania',
#  'systemu',
#  ',',
#  'które',
#  'wynikają',
#  'z',
#  'zastosowania',
#  'niskobudżetowego',
#  'napędu',
#  'liniowego',
#  '.',
#  'Efektem',
#  'tych',
#  'działań',
#  'będzie',
#  'otrzymanie',
#  'próbek',
#  'oraz',
#  'danych',
#  'z',
#  'procesu',
#  'beznarzędziowego',
#  'ciągnienia',
#  'o',
#  'wyższej',
#  'jakości',
#  '.',
#  '\n',
#  'Adaptacja',
#  'kodu',
#  'aplikacji',
#  'do',
#  'pracy',
#  'na',
#  'komputerze',
#  'stacjonarnym',
#  'zwiększy',
#  'częstotliwości',
#  'odczytu',
#  'wartości',
#  'z',
#  'czujnika',
#  'siły',
#  ',',
#  'wykonywania',
#  'zdjęć',
#  'próbki',
#  'oraz',
#  'podniesie',
#  'wydajność',
#  'algorytmu',
#  'analizującego',
#  'obraz',
#  'i',
#  'wyliczającego',
#  'wartość',
#  'odkształcenia',
#  'próbki',
#  '.',
#  'Wynikiem',
#  'zwiększenia',
#  'wydajności',
#  'tych',
#  'operacji',
#  'jest',
#  'uzyskanie',
#  'dokładniejszych',
#  'wykresów',
#  'naprężenia',
#  'od',
#  'odkształcenia',
#  'oraz',
#  'siły',
#  'od',
#  'wydłużenia',
#  'próbki',
#  '.',
#  'Ponadto',
#  'umożliwi',
#  'to',
#  'wykonywanie',
#  'statycznych',
#  'prób',
#  'rozciągania',
#  'przy',
#  'większych',
#  'prędkościach',
#  'odkształcenia',
#  'próbki',
#  '.',
#  '\n',
#  'Zamontowanie',
#  'enkodera',
#  'absolutnego',
#  'na',
#  'wale',
#  'silnika',
#  'odpowiedzialnego',
#  'za',
#  'rozciąganie',
#  'próbki',
#  'pozwoli',
#  'na',
#  'odczytywanie',
#  'jego',
#  'dokładnej',
#  'pozycji',
#  'w',
#  'dowolnym',
#  'momencie',
#  'trwania',
#  'procesu',
#  ',',
#  'a',
#  'także',
#  'umożliwi',
#  'pomiar',
#  'ilości',
#  'wykonanych',
#  'przez',
#  'silnik',
#  'kroków',
#  '.',
#  'Zaimplementowanie',
#  'algorytmu',
#  'wykorzystującego',
#  'te',
#  'dane',
#  'umożliwi',
#  'odczytywanie',
#  'zmiany',
#  'odkształcenia',
#  'oraz',
#  'średnicy',
#  'próbki',
#  'w',
#  'czasie',
#  'rzeczywisty',
#  ',',
#  'a',
#  'także',
#  'pozwoli',
#  'na',
#  'kontrolowanie',
#  'prędkości',
#  'odkształcenia',
#  'materiału',
#  '.']

# %%
df = remove_stop_words(df, nlp, 'description_tokens')

# %%
df['description_tokens'][0]
# Out:
# ['Tematem',
#  'niniejszej',
#  'pracy',
#  'rozwój',
#  'funkcjonalności',
#  'konstrukcji',
#  'maszyny',
#  'realizującej',
#  'proces',
#  'beznarzędziowego',
#  'ciągnienia',
#  '.',
#  '\n',
#  'Przebudowanie',
#  'systemu',
#  'transportu',
#  'układu',
#  'grzewczego',
#  'umożliwi',
#  'zminimalizowanie',
#  'zakłóceń',
#  'procesu',
#  'beznarzędziowego',
#  'ciągnienia',
#  'drgania',
#  'systemu',
#  ',',
#  'wynikają',
#  'zastosowania',
#  'niskobudżetowego',
#  'napędu',
#  'liniowego',
#  '.',
#  'Efektem',
#  'działań',
#  'otrzymanie',
#  'próbek',
#  'danych',
#  'procesu',
#  'beznarzędziowego',
#  'ciągnienia',
#  'wyższej',
#  'jakości',
#  '.',
#  '\n',
#  'Adaptacja',
#  'kodu',
#  'aplikacji',
#  'pracy',
#  'komputerze',
#  'stacjonarnym',
#  'zwiększy',
#  'częstotliwości',
#  'odczytu',
#  'wartości',
#  'czujnika',
#  'siły',
#  ',',
#  'wykonywania',
#  'zdjęć',
#  'próbki',
#  'podniesie',
#  'wydajność',
#  'algorytmu',
#  'analizującego',
#  'obraz',
#  'wyliczającego',
#  'wartość',
#  'odkształcenia',
#  'próbki',
#  '.',
#  'Wynikiem',
#  'zwiększenia',
#  'wydajności',
#  'operacji',
#  'uzyskanie',
#  'dokładniejszych',
#  'wykresów',
#  'naprężenia',
#  'odkształcenia',
#  'siły',
#  'wydłużenia',
#  'próbki',
#  '.',
#  'Ponadto',
#  'umożliwi',
#  'wykonywanie',
#  'statycznych',
#  'prób',
#  'rozciągania',
#  'większych',
#  'prędkościach',
#  'odkształcenia',
#  'próbki',
#  '.',
#  '\n',
#  'Zamontowanie',
#  'enkodera',
#  'absolutnego',
#  'wale',
#  'silnika',
#  'odpowiedzialnego',
#  'rozciąganie',
#  'próbki',
#  'pozwoli',
#  'odczytywanie',
#  'dokładnej',
#  'pozycji',
#  'dowolnym',
#  'momencie',
#  'trwania',
#  'procesu',
#  ',',
#  'umożliwi',
#  'pomiar',
#  'ilości',
#  'wykonanych',
#  'silnik',
#  'kroków',
#  '.',
#  'Zaimplementowanie',
#  'algorytmu',
#  'wykorzystującego',
#  'dane',
#  'umożliwi',
#  'odczytywanie',
#  'zmiany',
#  'odkształcenia',
#  'średnicy',
#  'próbki',
#  'czasie',
#  'rzeczywisty',
#  ',',
#  'pozwoli',
#  'kontrolowanie',
#  'prędkości',
#  'odkształcenia',
#  'materiału',
#  '.']

# %%
df = remove_stop_words(df, nlp, 'title_tokens')

# %%
df['title_tokens'][0]
# Out:
# ['Rozwój',
#  'funkcjonalności',
#  'modernizacja',
#  'konstrukcji',
#  'maszyny',
#  'realizującej',
#  'proces',
#  'beznarzędziowego',
#  'ciągnienia']

# %% [markdown]
# ## lower case tokens

# %%
df = lower_all_letters(df, 'description_tokens')
df['description_tokens'][0]
# Out:
# ['tematem',
#  'niniejszej',
#  'pracy',
#  'rozwój',
#  'funkcjonalności',
#  'konstrukcji',
#  'maszyny',
#  'realizującej',
#  'proces',
#  'beznarzędziowego',
#  'ciągnienia',
#  '.',
#  '\n',
#  'przebudowanie',
#  'systemu',
#  'transportu',
#  'układu',
#  'grzewczego',
#  'umożliwi',
#  'zminimalizowanie',
#  'zakłóceń',
#  'procesu',
#  'beznarzędziowego',
#  'ciągnienia',
#  'drgania',
#  'systemu',
#  ',',
#  'wynikają',
#  'zastosowania',
#  'niskobudżetowego',
#  'napędu',
#  'liniowego',
#  '.',
#  'efektem',
#  'działań',
#  'otrzymanie',
#  'próbek',
#  'danych',
#  'procesu',
#  'beznarzędziowego',
#  'ciągnienia',
#  'wyższej',
#  'jakości',
#  '.',
#  '\n',
#  'adaptacja',
#  'kodu',
#  'aplikacji',
#  'pracy',
#  'komputerze',
#  'stacjonarnym',
#  'zwiększy',
#  'częstotliwości',
#  'odczytu',
#  'wartości',
#  'czujnika',
#  'siły',
#  ',',
#  'wykonywania',
#  'zdjęć',
#  'próbki',
#  'podniesie',
#  'wydajność',
#  'algorytmu',
#  'analizującego',
#  'obraz',
#  'wyliczającego',
#  'wartość',
#  'odkształcenia',
#  'próbki',
#  '.',
#  'wynikiem',
#  'zwiększenia',
#  'wydajności',
#  'operacji',
#  'uzyskanie',
#  'dokładniejszych',
#  'wykresów',
#  'naprężenia',
#  'odkształcenia',
#  'siły',
#  'wydłużenia',
#  'próbki',
#  '.',
#  'ponadto',
#  'umożliwi',
#  'wykonywanie',
#  'statycznych',
#  'prób',
#  'rozciągania',
#  'większych',
#  'prędkościach',
#  'odkształcenia',
#  'próbki',
#  '.',
#  '\n',
#  'zamontowanie',
#  'enkodera',
#  'absolutnego',
#  'wale',
#  'silnika',
#  'odpowiedzialnego',
#  'rozciąganie',
#  'próbki',
#  'pozwoli',
#  'odczytywanie',
#  'dokładnej',
#  'pozycji',
#  'dowolnym',
#  'momencie',
#  'trwania',
#  'procesu',
#  ',',
#  'umożliwi',
#  'pomiar',
#  'ilości',
#  'wykonanych',
#  'silnik',
#  'kroków',
#  '.',
#  'zaimplementowanie',
#  'algorytmu',
#  'wykorzystującego',
#  'dane',
#  'umożliwi',
#  'odczytywanie',
#  'zmiany',
#  'odkształcenia',
#  'średnicy',
#  'próbki',
#  'czasie',
#  'rzeczywisty',
#  ',',
#  'pozwoli',
#  'kontrolowanie',
#  'prędkości',
#  'odkształcenia',
#  'materiału',
#  '.']

# %%
df = lower_all_letters(df, 'title_tokens')
df['title_tokens'][0]
# Out:
# ['rozwój',
#  'funkcjonalności',
#  'modernizacja',
#  'konstrukcji',
#  'maszyny',
#  'realizującej',
#  'proces',
#  'beznarzędziowego',
#  'ciągnienia']

# %% [markdown]
# ## puctuation removal

# %%
df = remove_punctuation(df, nlp, 'description_tokens')
df['description_tokens'][0]
# Out:
# ['tematem',
#  'niniejszej',
#  'pracy',
#  'rozwój',
#  'funkcjonalności',
#  'konstrukcji',
#  'maszyny',
#  'realizującej',
#  'proces',
#  'beznarzędziowego',
#  'ciągnienia',
#  '\n',
#  'przebudowanie',
#  'systemu',
#  'transportu',
#  'układu',
#  'grzewczego',
#  'umożliwi',
#  'zminimalizowanie',
#  'zakłóceń',
#  'procesu',
#  'beznarzędziowego',
#  'ciągnienia',
#  'drgania',
#  'systemu',
#  'wynikają',
#  'zastosowania',
#  'niskobudżetowego',
#  'napędu',
#  'liniowego',
#  'efektem',
#  'działań',
#  'otrzymanie',
#  'próbek',
#  'danych',
#  'procesu',
#  'beznarzędziowego',
#  'ciągnienia',
#  'wyższej',
#  'jakości',
#  '\n',
#  'adaptacja',
#  'kodu',
#  'aplikacji',
#  'pracy',
#  'komputerze',
#  'stacjonarnym',
#  'zwiększy',
#  'częstotliwości',
#  'odczytu',
#  'wartości',
#  'czujnika',
#  'siły',
#  'wykonywania',
#  'zdjęć',
#  'próbki',
#  'podniesie',
#  'wydajność',
#  'algorytmu',
#  'analizującego',
#  'obraz',
#  'wyliczającego',
#  'wartość',
#  'odkształcenia',
#  'próbki',
#  'wynikiem',
#  'zwiększenia',
#  'wydajności',
#  'operacji',
#  'uzyskanie',
#  'dokładniejszych',
#  'wykresów',
#  'naprężenia',
#  'odkształcenia',
#  'siły',
#  'wydłużenia',
#  'próbki',
#  'ponadto',
#  'umożliwi',
#  'wykonywanie',
#  'statycznych',
#  'prób',
#  'rozciągania',
#  'większych',
#  'prędkościach',
#  'odkształcenia',
#  'próbki',
#  '\n',
#  'zamontowanie',
#  'enkodera',
#  'absolutnego',
#  'wale',
#  'silnika',
#  'odpowiedzialnego',
#  'rozciąganie',
#  'próbki',
#  'pozwoli',
#  'odczytywanie',
#  'dokładnej',
#  'pozycji',
#  'dowolnym',
#  'momencie',
#  'trwania',
#  'procesu',
#  'umożliwi',
#  'pomiar',
#  'ilości',
#  'wykonanych',
#  'silnik',
#  'kroków',
#  'zaimplementowanie',
#  'algorytmu',
#  'wykorzystującego',
#  'dane',
#  'umożliwi',
#  'odczytywanie',
#  'zmiany',
#  'odkształcenia',
#  'średnicy',
#  'próbki',
#  'czasie',
#  'rzeczywisty',
#  'pozwoli',
#  'kontrolowanie',
#  'prędkości',
#  'odkształcenia',
#  'materiału']

# %%
df = remove_punctuation(df, nlp, 'title_tokens')
df['title_tokens'][0]
# Out:
# ['rozwój',
#  'funkcjonalności',
#  'modernizacja',
#  'konstrukcji',
#  'maszyny',
#  'realizującej',
#  'proces',
#  'beznarzędziowego',
#  'ciągnienia']

# %% [markdown]
# ## Remove \n \t \r char

# %%
df = remove_special_characters(df, 'description_tokens')
df['description_tokens'][0]
# Out:
# ['tematem',
#  'niniejszej',
#  'pracy',
#  'rozwój',
#  'funkcjonalności',
#  'konstrukcji',
#  'maszyny',
#  'realizującej',
#  'proces',
#  'beznarzędziowego',
#  'ciągnienia',
#  'przebudowanie',
#  'systemu',
#  'transportu',
#  'układu',
#  'grzewczego',
#  'umożliwi',
#  'zminimalizowanie',
#  'zakłóceń',
#  'procesu',
#  'beznarzędziowego',
#  'ciągnienia',
#  'drgania',
#  'systemu',
#  'wynikają',
#  'zastosowania',
#  'niskobudżetowego',
#  'napędu',
#  'liniowego',
#  'efektem',
#  'działań',
#  'otrzymanie',
#  'próbek',
#  'danych',
#  'procesu',
#  'beznarzędziowego',
#  'ciągnienia',
#  'wyższej',
#  'jakości',
#  'adaptacja',
#  'kodu',
#  'aplikacji',
#  'pracy',
#  'komputerze',
#  'stacjonarnym',
#  'zwiększy',
#  'częstotliwości',
#  'odczytu',
#  'wartości',
#  'czujnika',
#  'siły',
#  'wykonywania',
#  'zdjęć',
#  'próbki',
#  'podniesie',
#  'wydajność',
#  'algorytmu',
#  'analizującego',
#  'obraz',
#  'wyliczającego',
#  'wartość',
#  'odkształcenia',
#  'próbki',
#  'wynikiem',
#  'zwiększenia',
#  'wydajności',
#  'operacji',
#  'uzyskanie',
#  'dokładniejszych',
#  'wykresów',
#  'naprężenia',
#  'odkształcenia',
#  'siły',
#  'wydłużenia',
#  'próbki',
#  'ponadto',
#  'umożliwi',
#  'wykonywanie',
#  'statycznych',
#  'prób',
#  'rozciągania',
#  'większych',
#  'prędkościach',
#  'odkształcenia',
#  'próbki',
#  'zamontowanie',
#  'enkodera',
#  'absolutnego',
#  'wale',
#  'silnika',
#  'odpowiedzialnego',
#  'rozciąganie',
#  'próbki',
#  'pozwoli',
#  'odczytywanie',
#  'dokładnej',
#  'pozycji',
#  'dowolnym',
#  'momencie',
#  'trwania',
#  'procesu',
#  'umożliwi',
#  'pomiar',
#  'ilości',
#  'wykonanych',
#  'silnik',
#  'kroków',
#  'zaimplementowanie',
#  'algorytmu',
#  'wykorzystującego',
#  'dane',
#  'umożliwi',
#  'odczytywanie',
#  'zmiany',
#  'odkształcenia',
#  'średnicy',
#  'próbki',
#  'czasie',
#  'rzeczywisty',
#  'pozwoli',
#  'kontrolowanie',
#  'prędkości',
#  'odkształcenia',
#  'materiału']

# %%
df = remove_special_characters(df, 'title_tokens')
df['title_tokens'][0]
# Out:
# ['rozwój',
#  'funkcjonalności',
#  'modernizacja',
#  'konstrukcji',
#  'maszyny',
#  'realizującej',
#  'proces',
#  'beznarzędziowego',
#  'ciągnienia']

# %%
feature_half_way = os.path.join(path_to_feature_data, 'before_lemmatization.pickle')
# with open(feature_half_way, 'wb') as f:
#     df.to_pickle(f)

df = pd.read_pickle(feature_half_way)

# %% [markdown]
# ## Stemming

# %%
df = lematize_column(df, nlp, 'description_tokens')

# %%
df['description_tokens'][0]
# Out:
# ['temat',
#  'niniejszy',
#  'praca',
#  'rozwój',
#  'funkcjonalność',
#  'konstrukcja',
#  'maszyna',
#  'realizuć',
#  'proces',
#  'beznarzędziowy',
#  'ciągnieć',
#  'przebudowanie',
#  'system',
#  'transport',
#  'układ',
#  'grzewcz',
#  'umożliwić',
#  'zminimalizować',
#  'zakłócenie',
#  'proces',
#  'beznarzędziowy',
#  'ciągnieć',
#  'drganie',
#  'system',
#  'wynikać',
#  'zastosować',
#  'niskobudżetowy',
#  'napęd',
#  'liniowy',
#  'efekt',
#  'działanie',
#  'otrzymać',
#  'próbka',
#  'dane',
#  'proces',
#  'beznarzędziowy',
#  'ciągnieć',
#  'wyższej',
#  'jakość',
#  'adaptacja',
#  'kod',
#  'aplikacja',
#  'praca',
#  'komputer',
#  'stacjonarny',
#  'zwiększyć',
#  'częstotliwość',
#  'odczyt',
#  'wartość',
#  'czujnik',
#  'siła',
#  'wykonywać',
#  'zdjęcie',
#  'próbka',
#  'podnieść',
#  'wydajność',
#  'algorytm',
#  'analizujący',
#  'obraz',
#  'wyliczający',
#  'wartość',
#  'odkształceć',
#  'próbka',
#  'wynik',
#  'zwiększyć',
#  'wydajność',
#  'operacja',
#  'uzyskać',
#  'dokładniejszy',
#  'wykres',
#  'naprężenie',
#  'odkształcenie',
#  'siła',
#  'wydłużeć',
#  'próbka',
#  'ponadto',
#  'umożliwić',
#  'wykonywać',
#  'statyczny',
#  'próba',
#  'rozciągać',
#  'większych',
#  'prędkościach',
#  'odkształceć',
#  'próbka',
#  'zamontować',
#  'enkoder',
#  'absolutn',
#  'wale',
#  'silnik',
#  'odpowiedzialny',
#  'rozciąganie',
#  'próbka',
#  'pozwolić',
#  'odczytywać',
#  'dokładny',
#  'pozycja',
#  'dowolny',
#  'moment',
#  'trwać',
#  'proces',
#  'umożliwić',
#  'pomiar',
#  'ilość',
#  'wykonany',
#  'silnik',
#  'krok',
#  'zaimplementować',
#  'algorytm',
#  'wykorzystujący',
#  'dane',
#  'umożliwić',
#  'odczytywać',
#  'zmiana',
#  'odkształceć',
#  'średnica',
#  'próbka',
#  'czas',
#  'rzeczywist',
#  'pozwolić',
#  'kontrolować',
#  'prędkość',
#  'odkształceć',
#  'materiał']

# %%
df = lematize_column(df, nlp, 'title_tokens')

# %%
df['title_tokens'][0]
# Out:
# ['rozwój',
#  'funkcjonalność',
#  'modernizacja',
#  'konstrukcja',
#  'maszyna',
#  'realizuć',
#  'proces',
#  'beznarzędziowy',
#  'ciągnieć']

# %%
df
# Out:
#                                                   title  \
# 0     Rozwój funkcjonalności oraz modernizacja konst...
# 1     Opracowanie rusztowania na bazie wełny owczej ...
# 2     Papierowe systemy analityczne z mikroprzepływe...
# 3     System wizyzjny odczytujący osobom niewidomym ...
# 4     System wizyzjny nakierowujący osoby niewidome ...
# ...                                                 ...
# 5306                Biznesplan sklepu z odzieżą używaną
# 5307  Ewolucja bankowości elektronicznej w Polsce na...
# 5308  Ocena wykonania budżetu jednostki samorządu te...
# 5309  Rozwiązania smart-city stosowane dla krakowski...
# 5310  Analiza pierwotnego rynku nieruchomości lokalo...
#
#                                             description     category  \
# 0     Tematem niniejszej pracy jest rozwój funkcjona...  magisterska
# 1     Niniejsza praca dyplomowa skupia się na opraco...  inżynierska
# 2     Praca dotyczy prostych systemów diagnostycznyc...  inżynierska
# 3     Celem pracy jest stworzenie systemu wizyjnego,...  inżynierska
# 4     Celem pracy jest stworzenie systemu wizyjnego,...  inżynierska
# ...                                                 ...          ...
# 5306  W pracy zostaną przedstawione kolejne etapy po...  licencjacka
# 5307  W pracy dokonano opisu rozwoju bankowości elek...  licencjacka
# 5308  W pracy zostanie przedstawiony planowany budże...  licencjacka
# 5309  W pracy przedstawione zostanie zainteresowanie...  inżynierska
# 5310  Praca wymaga przeprowadzenia analizy statystyc...  inżynierska
#
#                                      description_tokens  \
# 0     [temat, niniejszy, praca, rozwój, funkcjonalno...
# 1     [niniejszy, praca, dyplomowy, skupiać, opracow...
# 2     [praca, dotyczyć, prosty, system, diagnostyczn...
# 3     [cel, praca, stworzyć, system, wizyjn, móc by,...
# 4     [cel, praca, stworzyć, system, wizyjn, móc by,...
# ...                                                 ...
# 5306  [w, praca, zostać, przedstawić, kolejny, etap,...
# 5307  [w, praca, dokonać, opis, rozwój, bankowość, e...
# 5308  [w, praca, zostać, przedstawić, planować, budż...
# 5309  [w, praca, przedstawić, zostać, zainteresowani...
# 5310  [praca, wymagać, przeprowadzić, analiza, staty...
#
#                                            title_tokens
# 0     [rozwój, funkcjonalność, modernizacja, konstru...
# 1     [opracować, rusztowanie, baza, wełna, owczy, r...
# 2     [papierowy, system, analityczny, mikroprzepływ...
# 3     [system, wizyzjny, odczytuć, osoba, niewidomym...
# 4     [system, wizyzjny, nakierowujący, osoba, niewi...
# ...                                                 ...
# 5306              [biznesplan, sklep, odzieżeć, używać]
# 5307  [ewolucja, bankowość, elektroniczny, Polska, p...
# 5308  [ocena, wykonać, budżet, jednostka, samorząd, ...
# 5309  [rozwiązać, smarta, cit, stosować, krakowski, ...
# 5310  [analiza, pierwotny, rynek, nieruchomość, loka...
#
# [5132 rows x 5 columns]

# %%
tokens_lematized = os.path.join(path_to_feature_data, 'tokens_lematized.pickle')

with open(tokens_lematized, 'wb') as f:
    df.to_pickle(f)

# %%
df = pd.read_pickle(tokens_lematized)

# %%
df['category'] = df['category'].apply(lambda x: x.replace('\n', ' '))
df['category'] = df['category'].apply(lambda x: x.split(', '))
df['category'][8]
# Out:
# ['inżynierska', 'magisterska']

# %%
title_and_description_tokenized_includes_polish_letters = os.path.join(path_to_feature_data, 'title_and_description_tokenized_includes_polish_letters.pickle')

with open(title_and_description_tokenized_includes_polish_letters, 'wb') as f:
    df.to_pickle(f)

# %%
df = pd.read_pickle(title_and_description_tokenized_includes_polish_letters)
df['title_tokens'][0]
# Out:
# ['rozwój',
#  'funkcjonalność',
#  'modernizacja',
#  'konstrukcja',
#  'maszyna',
#  'realizuć',
#  'proces',
#  'beznarzędziowy',
#  'ciągnieć']
